# %% [markdown]
# # Problem 1
# Bir sayının çift olup olmadığını sorgulayan bir fonksiyon yazın. Bu fonksiyon, eğer sayı çift ise bu değeri dönsün. Ancak sayı tek sayı ise fonksiyon raise ile ValueError hatası oluştursun. Daha sonra, içinde çift ve tek sayılar bulunduran bir liste tanımlayın ve liste üzerinde gezinerek ekrana sadece çift sayıları bastırın.

# %%
def ciftsayi(liste):
    for i in liste:
        if i%2==0 :
            print(i)
        else:
            raise ValueError("listede tek sayi var")
ciftsayi([2,6,4,7])
# Out:
# 2
# 6
# 4
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-3fd18f2858c2> in <module>
#       5         else:
#       6             raise ValueError("listede tek sayi var")
# ----> 7 ciftsayi([2,6,4,7])
#
# <ipython-input-1-3fd18f2858c2> in ciftsayi(liste)
#       4             print(i)
#       5         else:
# ----> 6             raise ValueError("listede tek sayi var")
#       7 ciftsayi([2,6,4,7])
#
# ValueError: listede tek sayi var

# %% [markdown]
# # Problem 2
#
# 2 YetGen lideri ders sırasında canları sıkılınca oyun oynamak isterler. Ancak hangi oyunu oynayacaklarına karar veremezler ve son olarak kendi oyunlarını yazmaya karar verirler.
# Liderlerimizin kodlamak istediği oyun kuralları şöyledir:
# - Oyunda random olarak 0 ile 100 arasında bir sayı tutulur.
# - Kullanıcıdan bilgisayarın tuttuğu sayıyı tahmin etmesi için bir sayı girmesini istenir.
# - Eğer kullanıcının girdiği sayı bulunması gereken sayıdan küçükse  tahmininizi yükseltin, büyükse tahmininizi düşürün şeklinde bir çıktı verilir.
# - Oyunun gerçeğe yakın olması için bilgisayarın çalışmasını simgelemek için 1 saniye bekleme süresi tanınır.
# - Kullanıcı 5 hakkı vardır. 5 hakkı da kullanıp sayıyı bulamazsa oyunu kaybeder.

# %%
import random
import time

print("****** Sayi Tahmnin Oyunu:1 ile 100 arasinda bir sayi tahmnin ediniz.*********")

rastgele_sayi = random.randint(1,100)
tahmin_hakki=5

while True:
    tahmin=int(input("Tahmin ettiginiz sayi kactir :"))
    if(tahmin<rastgele_sayi):
        print("degeriniz kontrol ediliyor.......")
        time.sleep(1)

        print("HAHAHA bilemedin. Daha yüksek bir sayi söyle :)")
        
        tahmin_hakki-=1

    elif(tahmin>rastgele_sayi):
        print("degeriniz kontrol ediliyor.......")
        time.sleep(1)
        
        print("HAHAHA bilemedin. Daha kucuk bir sayi soyle :)")
        
        tahmin_hakki-=1


    else:
        print("Degeriniz kontrol ediliyor.......")
        time.sleep(1)

        print("Tebrikler! Maalesef sayiyi bildin... ", rastgele_sayi)
        break

    if(tahmin_hakki==0):
        print("Tahmin hakkiniz bitti....")
        print("bilemedigin sayi:", rastgele_sayi)
        break
# Out:
# ****** Sayi Tahmnin Oyunu:1 ile 100 arasinda bir sayi tahmnin ediniz.*********
# degeriniz kontrol ediliyor.......
# HAHAHA bilemedin. Daha yüksek bir sayi söyle :)
# degeriniz kontrol ediliyor.......
# HAHAHA bilemedin. Daha kucuk bir sayi soyle :)
# degeriniz kontrol ediliyor.......
# HAHAHA bilemedin. Daha kucuk bir sayi soyle :)
# degeriniz kontrol ediliyor.......
# HAHAHA bilemedin. Daha kucuk bir sayi soyle :)
# degeriniz kontrol ediliyor.......
# HAHAHA bilemedin. Daha kucuk bir sayi soyle :)
# Tahmin hakkiniz bitti....
# bilemedigin sayi: 41
